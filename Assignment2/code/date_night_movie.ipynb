# %% [markdown]
# # Date Night Movie
#
# #### Grading:
#
#
# - Code: 90 pts
# - Markdown Documentation: 10 pts

# %% [markdown]
# In this assignment we are going to use pandas to figure out - What's the best **date-night movie**?
#
# This assignment is going to use
# - Joining
# - Groupby
# - Sorting

# %%
import os
import pandas as pd

# %% [markdown]
# ##### Read in the movie data: `pd.read_table`

# %%
def get_movie_data():
    
    unames = ['user_id','gender','age','occupation','zip']
    users = pd.read_table(os.path.join('../data','users.dat'), 
                          sep='::', header=None, names=unames)
    
    rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
    ratings = pd.read_table(os.path.join('../data', 'ratings.dat'), 
                            sep='::', header=None, names=rnames)
    
    mnames = ['movie_id', 'title','genres']
    movies = pd.read_table(os.path.join('../data', 'movies.dat'), 
                           sep='::', header=None, names=mnames)

    return users, ratings, movies

# %%
users, ratings, movies = get_movie_data()
# Out:
# C:\Users\harin\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# C:\Users\harin\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# C:\Users\harin\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   del sys.path[0]

# %%
users.head()
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
movies.head()
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %% [markdown]
# ##### Clean up the `movies`
#
# - Get the `year`
# - Shorten the `title`

# %%
tmp = movies.title.str.extract('(.*) \(([0-9]+)\)')
tmp.apply(lambda x:x[0] if len(x) > 0 else None)
tmp.apply(lambda x: x[0][:40] if len(x) > 0 else None)
# Out:
# 0    Toy Story
# 1         1995
# dtype: object

# %%
movies['year'] = tmp[1]
movies['short_title'] = tmp[0]

# %%
movies.head()
# Out:
#    movie_id                               title                        genres  \
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
#
#    year                  short_title
# 0  1995                    Toy Story
# 1  1995                      Jumanji
# 2  1995             Grumpier Old Men
# 3  1995            Waiting to Exhale
# 4  1995  Father of the Bride Part II

# %% [markdown]
# ##### Join the tables with `pd.merge` (20 pts)

# %% [markdown]
# ## Merge Users and ratings first since it is a one-to-many relationship

# %%
#merges users and ratings based on user_id
UserRatingMerge = pd.merge(users,ratings, on = ["user_id"])
UserRatingMerge.head()
# Out:
#    user_id gender  age  occupation    zip  movie_id  rating  timestamp
# 0        1      F    1          10  48067      1193       5  978300760
# 1        1      F    1          10  48067       661       3  978302109
# 2        1      F    1          10  48067       914       3  978301968
# 3        1      F    1          10  48067      3408       4  978300275
# 4        1      F    1          10  48067      2355       5  978824291

# %% [markdown]
# ## Merge the merged dataset with movies dataset to get a super merged dataframe.

# %%
SuperMovie = pd.merge(movies,UserRatingMerge, on = ["movie_id"])
#sorts by user id to make sure merge was correct and that all users are in the dataset. 
SuperMovie.sort_values(by=['user_id']).head()
# Out:
#         movie_id                         title                       genres  \
# 0              1              Toy Story (1995)  Animation|Children's|Comedy
# 310576      1207  To Kill a Mockingbird (1962)                        Drama
# 341051      1246     Dead Poets Society (1989)                        Drama
# 745569      2762       Sixth Sense, The (1999)                     Thriller
# 144754       531     Secret Garden, The (1993)             Children's|Drama
#
#         year            short_title  user_id gender  age  occupation    zip  \
# 0       1995              Toy Story        1      F    1          10  48067
# 310576  1962  To Kill a Mockingbird        1      F    1          10  48067
# 341051  1989     Dead Poets Society        1      F    1          10  48067
# 745569  1999       Sixth Sense, The        1      F    1          10  48067
# 144754  1993     Secret Garden, The        1      F    1          10  48067
#
#         rating  timestamp
# 0            5  978824268
# 310576       4  978300719
# 341051       4  978302091
# 745569       4  978302091
# 144754       4  978302149

# %% [markdown]
# ##### What's the highest rated movie? (20 pts))

# %% [markdown]
# ### Gets an average rating of all movies and determines the size which indicates how many times people have rated the movie. (higher size = better indication of rating)

# %%
RatedMov = SuperMovie[['title','rating']]
#Gets average of ratings per movie
AvgRatedMov = RatedMov.groupby(['title']).mean()
#Creates a new column (Size) which finds the amount of people who rated the movie
AvgRatedMov['Size'] = RatedMov.groupby(['title']).size().to_frame('size')

#finds most rated movie to get a better range. 
AvgRatedMov.sort_values(by = ['Size'], ascending = False).head()
# The highest amount of times a movie has been is 3428 times
# We will look for movies over 1000 size then when finding the highly rated movie.
# Out:
#                                                       rating  Size
# title
# American Beauty (1999)                              4.317386  3428
# Star Wars: Episode IV - A New Hope (1977)           4.453694  2991
# Star Wars: Episode V - The Empire Strikes Back ...  4.292977  2990
# Star Wars: Episode VI - Return of the Jedi (1983)   4.022893  2883
# Jurassic Park (1993)                                3.763847  2672

# %% [markdown]
# ### Display movies who have been rated at least a 1000 times and finds highly rated Movie.

# %%
#only count the movies that have been rated at least 1000 times by users
Top1000Movies = AvgRatedMov[AvgRatedMov['Size']>=1000]
#since we have movies that are rated over 1000 times, sort by ratings. 
HighRate_Mov = Top1000Movies.sort_values(['rating'],ascending = False)

#display and the top rating should be the highly rated movie. 
HighRate_Mov.head()
# Out:
#                                     rating  Size
# title
# Shawshank Redemption, The (1994)  4.554558  2227
# Godfather, The (1972)             4.524966  2223
# Usual Suspects, The (1995)        4.517106  1783
# Schindler's List (1993)           4.510417  2304
# Raiders of the Lost Ark (1981)    4.477725  2514

# %% [markdown]
# ## ANSWER: The Shawshank Redemption is the highly rated movie.

# %% [markdown]
# ###### What is a good rated movie for date night? (60 pts)
#
# - Hint - highly rated movie by
#     - both partners (might be the same gender or not),
#     - based on genre preferences,
#     - age group can also be combined

# %% [markdown]
# ## Remove unwanted variables and calculate the amount of times the movie has been reviewed.

# %%
#remove unwanted variables that have no contributation in finding a movie for date night. 
Short_mymov = SuperMovie.drop(["movie_id","user_id","short_title","occupation","zip","timestamp","year"], axis = 1)

#Calculate the size of how many times the movie has been reviewd. 
Rates['Size'] = Short_mymov.groupby(['title']).size().to_frame('size')

# %% [markdown]
# ## Select desired Genre.

# %%
DesiredMov = Rates[Rates['genres'].str.contains('Comedy')]

# %% [markdown]
# ## Group the variables together by title and genre, giving an average rating and age group of both genders.

# %%
#group tableset by title, genre.
#this will give an average rating of and age group of both genders together.
Avg = DesiredMov.groupby(['title','genres']).mean()

#sortby size to estimate the cutoff point where we decide the highly rated movie. 
Avg.sort_values(by = ['Size'], ascending = False).head()
# Out:
#                                                                   age  \
# title                      genres
# American Beauty (1999)     Comedy|Drama                     29.615228
# Back to the Future (1985)  Comedy|Sci-Fi                    29.895470
# Men in Black (1997)        Action|Adventure|Comedy|Sci-Fi   28.941686
# Shakespeare in Love (1998) Comedy|Romance                   30.564373
# Princess Bride, The (1987) Action|Adventure|Comedy|Romance  28.084556
#
#                                                               rating    Size
# title                      genres
# American Beauty (1999)     Comedy|Drama                     4.317386  3428.0
# Back to the Future (1985)  Comedy|Sci-Fi                    3.990321  2583.0
# Men in Black (1997)        Action|Adventure|Comedy|Sci-Fi   3.739953  2538.0
# Shakespeare in Love (1998) Comedy|Romance                   4.127480  2369.0
# Princess Bride, The (1987) Action|Adventure|Comedy|Romance  4.303710  2318.0

# %% [markdown]
# ## Only allow movies that have a size of 1000 or greater and set average age range to mid 20's.

# %%
#only count the movies that have been rated at least 1000 times by users
Top1000 = Avg[Avg['Size']>=1000]

#Set age group to mid 20's. 
MyDesiredMov = Top1000[(Top1000['age'] >= 20) & (Top1000['age'] < 28)]
MyDesiredMov
# Out:
#                                                                                                       age  \
# title                                              genres
# Aladdin (1992)                                     Animation|Children's|Comedy|Musical          26.297557
# American Pie (1999)                                Comedy                                       25.164147
# Austin Powers: International Man of Mystery (1997) Comedy                                       25.788382
# Austin Powers: The Spy Who Shagged Me (1999)       Comedy                                       26.319386
# Batman Returns (1992)                              Action|Adventure|Comedy|Crime                26.641125
# Bug's Life, A (1998)                               Animation|Children's|Comedy                  27.964768
# Clerks (1994)                                      Comedy                                       25.321530
# Clueless (1995)                                    Comedy|Romance                               27.286344
# Election (1999)                                    Comedy                                       27.539422
# Ferris Bueller's Day Off (1986)                    Comedy                                       27.949762
# Grosse Pointe Blank (1997)                         Comedy|Crime                                 27.396127
# Little Mermaid, The (1989)                         Animation|Children's|Comedy|Musical|Romance  26.693720
# Mars Attacks! (1996)                               Action|Comedy|Sci-Fi|War                     27.898510
# Mask, The (1994)                                   Comedy|Crime|Fantasy                         27.307040
# Rushmore (1998)                                    Comedy                                       26.613934
# South Park: Bigger, Longer and Uncut (1999)        Animation|Comedy                             24.832939
# There's Something About Mary (1998)                Comedy                                       27.128373
# Toy Story (1995)                                   Animation|Children's|Comedy                  27.700530
# Toy Story 2 (1999)                                 Animation|Children's|Comedy                  27.743218
# Wayne's World (1992)                               Comedy                                       26.901786
# Willy Wonka and the Chocolate Factory (1971)       Adventure|Children's|Comedy|Fantasy          27.042650
#
#                                                                                                   rating  \
# title                                              genres
# Aladdin (1992)                                     Animation|Children's|Comedy|Musical          3.788305
# American Pie (1999)                                Comedy                                       3.709863
# Austin Powers: International Man of Mystery (1997) Comedy                                       3.710373
# Austin Powers: The Spy Who Shagged Me (1999)       Comedy                                       3.388424
# Batman Returns (1992)                              Action|Adventure|Comedy|Crime                2.976722
# Bug's Life, A (1998)                               Animation|Children's|Comedy                  3.854375
# Clerks (1994)                                      Comedy                                       3.946884
# Clueless (1995)                                    Comedy|Romance                               3.623348
# Election (1999)                                    Comedy                                       3.930355
# Ferris Bueller's Day Off (1986)                    Comedy                                       4.117447
# Grosse Pointe Blank (1997)                         Comedy|Crime                                 3.813380
# Little Mermaid, The (1989)                         Animation|Children's|Comedy|Musical|Romance  3.756522
# Mars Attacks! (1996)                               Action|Comedy|Sci-Fi|War                     2.900372
# Mask, The (1994)                                   Comedy|Crime|Fantasy                         3.279050
# Rushmore (1998)                                    Comedy                                       3.840984
# South Park: Bigger, Longer and Uncut (1999)        Animation|Comedy                             3.760441
# There's Something About Mary (1998)                Comedy                                       3.904449
# Toy Story (1995)                                   Animation|Children's|Comedy                  4.146846
# Toy Story 2 (1999)                                 Animation|Children's|Comedy                  4.218927
# Wayne's World (1992)                               Comedy                                       3.600893
# Willy Wonka and the Chocolate Factory (1971)       Adventure|Children's|Comedy|Fantasy          3.861386
#
#                                                                                                   Size
# title                                              genres
# Aladdin (1992)                                     Animation|Children's|Comedy|Musical          1351.0
# American Pie (1999)                                Comedy                                       1389.0
# Austin Powers: International Man of Mystery (1997) Comedy                                       1205.0
# Austin Powers: The Spy Who Shagged Me (1999)       Comedy                                       1434.0
# Batman Returns (1992)                              Action|Adventure|Comedy|Crime                1031.0
# Bug's Life, A (1998)                               Animation|Children's|Comedy                  1703.0
# Clerks (1994)                                      Comedy                                       1412.0
# Clueless (1995)                                    Comedy|Romance                               1362.0
# Election (1999)                                    Comedy                                       1522.0
# Ferris Bueller's Day Off (1986)                    Comedy                                       1473.0
# Grosse Pointe Blank (1997)                         Comedy|Crime                                 1136.0
# Little Mermaid, The (1989)                         Animation|Children's|Comedy|Musical|Romance  1035.0
# Mars Attacks! (1996)                               Action|Comedy|Sci-Fi|War                     1074.0
# Mask, The (1994)                                   Comedy|Crime|Fantasy                         1179.0
# Rushmore (1998)                                    Comedy                                       1220.0
# South Park: Bigger, Longer and Uncut (1999)        Animation|Comedy                             1269.0
# There's Something About Mary (1998)                Comedy                                       1371.0
# Toy Story (1995)                                   Animation|Children's|Comedy                  2077.0
# Toy Story 2 (1999)                                 Animation|Children's|Comedy                  1585.0
# Wayne's World (1992)                               Comedy                                       1120.0
# Willy Wonka and the Chocolate Factory (1971)       Adventure|Children's|Comedy|Fantasy          1313.0

# %% [markdown]
# ## Sort Movies by highest rated.

# %%
#sort movies by highest rating
DateNight_Mov = MyDesiredMov.sort_values(['rating'],ascending = False)
DateNight_Mov[:5]
# Out:
#                                                                    age  \
# title                           genres
# Toy Story 2 (1999)              Animation|Children's|Comedy  27.743218
# Toy Story (1995)                Animation|Children's|Comedy  27.700530
# Ferris Bueller's Day Off (1986) Comedy                       27.949762
# Clerks (1994)                   Comedy                       25.321530
# Election (1999)                 Comedy                       27.539422
#
#                                                                rating    Size
# title                           genres
# Toy Story 2 (1999)              Animation|Children's|Comedy  4.218927  1585.0
# Toy Story (1995)                Animation|Children's|Comedy  4.146846  2077.0
# Ferris Bueller's Day Off (1986) Comedy                       4.117447  1473.0
# Clerks (1994)                   Comedy                       3.946884  1412.0
# Election (1999)                 Comedy                       3.930355  1522.0

# %% [markdown]
# # ANSWER: Toy Story 2 would be a good rated movie for date night.
